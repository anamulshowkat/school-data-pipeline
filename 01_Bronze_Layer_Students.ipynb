# %%
# %run "./00_Pipeline_Configurations"

# %%
# %run "./08_Audit_Log_Function"

# %%
# 01_Bronze_Layer_Students
from datetime import datetime

start_time = datetime.now()

try:
    df_students_raw = spark.read.csv(students_path, header=True, inferSchema=True)
    df_students_raw.write.format("delta").mode("overwrite").saveAsTable(bronze_students_table)

    display(df_students_raw)

    log_audit("bronze_students", table_name=bronze_students_table, status="SUCCESS", start_time=start_time)

except Exception as e:
    log_audit("bronze_students", status="FAILED", start_time=start_time, error_msg=str(e))
    raise
