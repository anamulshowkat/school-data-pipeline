# %%
# Databricks notebook: 00_Pipeline_Configurations
import uuid
# Config identity
config_id = str(uuid.uuid4())   # unique config id
pipeline_name = "school_data_pipeline"

# Source paths 
students_path = "/Workspace/Users/anaamshah9999@gmail.com/school-data-pipeline/volumes/school_students.csv"
attendance_path = "/Workspace/Users/anaamshah9999@gmail.com/school-data-pipeline/volumes/student_attendance_marks.csv"

# Students pipeline tables
bronze_students_table = "bronze_school_students"
silver_students_table = "silver_school_students"
gold_students_table = "gold_school_students"

# Attendance/Marks pipeline tables 
bronze_attendance_table = "bronze_student_attendance_marks"
silver_attendance_table = "silver_student_attendance_marks"
gold_attendance_table = "gold_student_attendance_marks"

# Final joined gold table
master_gold_table = "school_summary_final"

# Audit log table
audit_table = "audit_log_school_pipeline"

print("Config loaded successfully")
